# %%
def scrape(url):
    """Scrape URLs to generate previews."""
    import requests
    from bs4 import BeautifulSoup
    from time import sleep
    headers = requests.utils.default_headers()
    headers.update({
        'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
    })
    r = ""
    while r=="":
        try:
            r = requests.get(url, headers)
            break
        except:
            print("Connection refused by the server.. Sleep for 5 seconds")
            sleep(5)
            continue
    if not r.status_code == 200:
        return None
    raw_html = r.content
    soup = BeautifulSoup(raw_html, 'html.parser')
    return(soup)

# %%
def scrape_airline_df(results_page):
    """Convert previews from airlinequality.com to review dataframe."""
    import numpy as np
    import pandas as pd
    from datetime import datetime
    from bs4 import BeautifulSoup

    def safe_get(text):
        """Get the text if there is any, otherwise returns NaN."""
        return text.get_text() if text else pd.np.nan

    def safe_get_next(text):
        """Get the next sibling text if there is any, otherwise returns NaN."""
        return text.findNextSibling().get_text() if text else pd.np.nan

    def star_count(tag):
        """Convert logo stars into an integer."""
        return len(tag.findNextSibling().findAll("span", class_="star fill")) if tag else pd.np.nan

    reviews = results_page.find_all("article",  itemprop="review", itemscope="")
    review_list = list()

    for review in reviews:
        rating = review.find("div", class_="rating-10")
        id_ = review.find("div", class_="body")
        text_header = review.find("h2", class_="text_header")
        review_count = review.find("span", class_="userStatusReviewCount")
        name = review.find("span", itemprop="name")
        country = review.find("h3").findAll(text=True)[-2][2:-2]
        date_published = review.find("time")
        text = review.find("div", class_="text_content")
        traveller_type = review.find("td", class_="review-rating-header type_of_traveller")
        seat_type = review.find("td", class_="review-rating-header cabin_flown")
        route = review.find("td", class_="review-rating-header route")
        date_flown = review.find("td", class_="review-rating-header date_flown")
        seat_comfort = review.find("td", class_="review-rating-header seat_comfort")
        cabin_service = review.find("td", class_="review-rating-header cabin_staff_service")
        ground_service = review.find("td", class_="review-rating-header ground_service")
        value_for_money = review.find("td", class_="review-rating-header value_for_money")
        recommended = review.find("td", class_="review-rating-header recommended")
        review_dict = {
            "rating": rating.get_text() if rating else pd.np.nan,
            "id": id_.get("id") if id_ else pd.np.nan,
            "text_header": safe_get(text_header),
            "review_count": int(review_count.get_text()[:-8]) if review_count else 0,
            "name": safe_get(name),
            "country": country,
            "date_published":datetime.strptime(date_published.get("datetime"), "%Y-%m-%d") if date_published else pd.np.nan,
            "text": safe_get(text),
            "traveller_type": safe_get_next(traveller_type),
            "seat_type": safe_get_next(seat_type),
            "route": safe_get_next(route),
            "date_flown": datetime.strptime(safe_get_next(date_flown), "%B %Y") if date_flown else pd.np.nan,
            "seat_comfort": star_count(seat_comfort),
            "cabin_service": star_count(cabin_service),
            "ground_service": star_count(ground_service),
            "value_for_money": star_count(value_for_money),
            "recommended": pd.np.nan if not recommended else \
                            1 if recommended.findNextSibling().get_text()=="yes" else 0
        }
        review_list.append(review_dict)
    return pd.DataFrame.from_dict(review_list)

# %%
"""Get all airline_name and airline_code from airlinequality.com."""
import pandas as pd
url_all = "https://www.airlinequality.com/review-pages/a-z-airline-reviews/"
AZweb = scrape(url_all)
airlines = AZweb.find("div", class_="tabs-content").select("a")
airline_list = list()

for airline in airlines:
    airline_name = airline.get_text()
    airline_code =  airline.get("href")[17:]  # 17 to remove "/airline-reviews/" 
    airline_list.append((airline_name, airline_code))

airline_df = pd.DataFrame(airline_list, columns = ["airline_name", "airline_code"])

# %%
"""Get all raw reviews data from airlinequality.com."""
from IPython.display import clear_output

reviews_raw = pd.DataFrame()
airline_raw_list = list()
counter = 0
for (airline_name,airline_code) in zip(airline_df["airline_name"], airline_df["airline_code"]):
    url = "https://www.airlinequality.com/airline-reviews/" + airline_code + \
                                "/page/1/?sortby=post_date%3ADesc&pagesize=50000"
    soup = scrape(url)
    airline_raw_dict = {
        "airline_name": airline_name,
        "airline_code": airline_code,
        "airline_raw_data": soup
    }
    airline_raw_list.append(airline_raw_dict)
    new_df = scrape_airline_df(soup)
    new_df["airline_name"] = airline_name
    new_df["airline_code"] = airline_code
    reviews_raw = reviews_raw.append(new_df)
    clear_output()
    counter +=1
    percent_to_be_done = round(counter/len(airline_df) * 100)
    print(counter, " out of ", len(airline_df), "is done: ", percent_to_be_done, "%")
# Out:
# 496  out of  496 is done:  100 %

# %%
reviews_raw
# Out:
#     cabin_service               country           date_flown date_published  \
# 0             2.0        United Kingdom  2019-06-01 00:00:00     2019-06-25
# 1             1.0        United Kingdom  2019-06-01 00:00:00     2019-06-25
# 0             4.0               Germany  2018-10-01 00:00:00     2018-10-12
# 1             1.0               Germany  2018-10-01 00:00:00     2018-10-05
# 2             1.0         United States  2018-07-01 00:00:00     2018-07-29
# 3             3.0                France  2018-05-01 00:00:00     2018-07-19
# 4             2.0              Slovenia  2018-06-01 00:00:00     2018-06-30
# 5             3.0        Czech Republic  2018-06-01 00:00:00     2018-06-24
# 6             5.0              Slovenia  2018-04-01 00:00:00     2018-05-04
# 7             1.0               Germany  2018-03-01 00:00:00     2018-03-11
# 8             4.0         United States  2017-09-01 00:00:00     2017-12-05
# 9             5.0              Slovenia  2017-11-01 00:00:00     2017-11-20
# 10            3.0               Finland  2017-10-01 00:00:00     2017-10-27
# 11            4.0         United States  2017-06-01 00:00:00     2017-09-16
# 12            5.0           Switzerland  2017-04-01 00:00:00     2017-04-19
# 13            5.0               Austria  2016-12-01 00:00:00     2017-01-27
# 14            5.0              Slovenia  2016-10-01 00:00:00     2016-11-10
# 15            4.0             Singapore  2016-11-01 00:00:00     2016-11-09
# 16            5.0              Slovenia  2016-11-01 00:00:00     2016-11-03
# 17            1.0             Australia  2016-10-01 00:00:00     2016-10-21
# 18            1.0           Netherlands  2016-10-01 00:00:00     2016-10-10
# 19            2.0              Slovenia  2016-08-01 00:00:00     2016-09-30
# 20            4.0        United Kingdom  2016-09-01 00:00:00     2016-09-04
# 21            5.0        United Kingdom  2016-07-01 00:00:00     2016-08-06
# 22            5.0               Estonia  2016-07-01 00:00:00     2016-07-29
# 23            4.0         United States  2016-07-01 00:00:00     2016-07-13
# 24            5.0              Slovenia  2016-07-01 00:00:00     2016-07-11
# 25            2.0                Poland  2016-07-01 00:00:00     2016-07-10
# 26            3.0         United States  2016-01-01 00:00:00     2016-01-25
# 27            3.0              Slovenia  2015-09-01 00:00:00     2015-12-04
# ..            ...                   ...                  ...            ...
# 0             2.0        United Kingdom  2017-09-01 00:00:00     2017-09-26
# 1             5.0             Australia                  NaT     2013-05-01
# 2             NaN             Australia                  NaT     2012-07-05
# 3             NaN               Germany                  NaT     2009-03-10
# 0             NaN        United Kingdom                  NaN     2011-10-09
# 1             NaN                 India                  NaN     2011-08-11
# 2             NaN              Djibouti                  NaN     2011-07-18
# 3             NaN              Ethiopia                  NaN     2011-06-13
# 4             NaN  United Arab Emirates                  NaN     2011-06-04
# 5             NaN                 India                  NaN     2011-05-19
# 6             NaN  United Arab Emirates                  NaN     2011-04-30
# 7             NaN        United Kingdom                  NaN     2011-04-25
# 8             NaN          Saudi Arabia                  NaN     2010-02-14
# 9             NaN        United Kingdom                  NaN     2009-07-17
# 10            NaN                                        NaN     2009-03-10
# 11            NaN                                        NaN     2009-02-18
# 12            NaN                                        NaN     2008-05-30
# 13            NaN                                        NaN     2008-05-16
# 14            NaN                                        NaN     2008-04-07
# 15            NaN                                        NaN     2007-01-29
# 16            NaN                                        NaN     2006-10-18
# 17            NaN                                        NaN     2006-04-11
# 18            NaN                                        NaN     2006-01-26
# 19            NaN                                        NaN     2005-11-29
# 20            NaN                                        NaN     2004-01-09
# 21            NaN                                        NaN     2003-11-17
# 22            NaN                                        NaN     2003-10-23
# 23            NaN                                        NaN     2003-05-06
# 0             4.0             Indonesia  2018-12-01 00:00:00     2019-01-05
# 1             5.0                 Nepal  2016-06-01 00:00:00     2016-07-23
#
#     ground_service            id                   name  \
# 0              1.0  anchor666859          Gyan Fernando
# 1              1.0  anchor666802          Gyan Fernando
# 0              5.0  anchor612920                M Jager
# 1              1.0  anchor611417           Giulia Rossi
# 2              4.0  anchor595049           Galya Slavov
# 3              3.0  anchor592506             Loic Jouan
# 4              2.0  anchor587586               P Gamirj
# 5              1.0  anchor586201                B Haruz
# 6              5.0  anchor567813          Michel Zombra
# 7              1.0  anchor554731            S Hanarosic
# 8              1.0  anchor533715               P Gregan
# 9              5.0  anchor530744              G Vincent
# 10             1.0  anchor526087                A Kalen
# 11             1.0  anchor516969            J Marikovic
# 12             5.0  anchor478732        Alexander Stare
# 13             5.0  anchor461141       Andreas Hartlieb
# 14             5.0  anchor442065               G Victor
# 15             3.0  anchor441947           Bojan Tercon
# 16             4.0  anchor440765                L Benko
# 17             3.0  anchor437775                B Rudac
# 18             2.0  anchor435477               C Ransen
# 19             4.0  anchor433394             G Korjacan
# 20             3.0  anchor427486            Ian Andrews
# 21             1.0  anchor419465       Mike Whittingham
# 22             5.0  anchor417279  Toomas Kristjan Käbin
# 23             5.0  anchor412596               R Sanyal
# 24             5.0  anchor412018              G Vincent
# 25             4.0  anchor411785              M Osiecki
# 26             3.0  anchor373669                D Marks
# 27             3.0  anchor360736                M Sepic
# ..             ...           ...                    ...
# 0              2.0  anchor519212           Mark Ellwood
# 1              NaN  anchor275208              Jeff Nash
# 2              NaN  anchor275205             Rob Briggs
# 3              NaN  anchor275206      Reinhard Kaempfer
# 0              NaN  anchor275220            M Alexander
# 1              NaN  anchor275221       Aagar Sambasivan
# 2              NaN  anchor275222       Abdourahman Bakr
# 3              NaN  anchor275223        Ermias Yohannis
# 4              NaN  anchor275224               P Yogesh
# 5              NaN  anchor275225            Bharti Khan
# 6              NaN  anchor275226          Eric Attheson
# 7              NaN  anchor275227            Ian Howarth
# 8              NaN  anchor275228          Roy Clogstoun
# 9              NaN  anchor275229             S Metcalfe
# 10             NaN  anchor275230              I Chernin
# 11             NaN  anchor275231             Jack Smith
# 12             NaN  anchor275232        Sahar Choudhury
# 13             NaN  anchor275209                 Z Khan
# 14             NaN  anchor275210           Nizar Bantan
# 15             NaN  anchor275211       Meghan Zimmerman
# 16             NaN  anchor275212          Olli Toivonen
# 17             NaN  anchor275213            Gill Holmes
# 18             NaN  anchor275214             Jane Geels
# 19             NaN  anchor275215         Sverre Daehlen
# 20             NaN  anchor275216                L Singh
# 21             NaN  anchor275217               Sam Park
# 22             NaN  anchor275218             David Howe
# 23             NaN  anchor275219              B Herdens
# 0              5.0  anchor631424     Ramnath Rangaswamy
# 1              4.0  anchor415722            Alok Mishra
#
#                                                rating  recommended  \
# 0                                            \n1/10\n          0.0
# 1                                            \n1/10\n          0.0
# 0                                            \n8/10\n          1.0
# 1                                            \n1/10\n          0.0
# 2                                            \n1/10\n          0.0
# 3                                            \n2/10\n          0.0
# 4                                            \n2/10\n          0.0
# 5                                            \n3/10\n          0.0
# 6                                           \n10/10\n          1.0
# 7                                            \n1/10\n          0.0
# 8                                            \n3/10\n          0.0
# 9                                            \n9/10\n          1.0
# 10                                           \n2/10\n          0.0
# 11                                           \n2/10\n          0.0
# 12                                           \n9/10\n          1.0
# 13                                           \n8/10\n          1.0
# 14                                          \n10/10\n          1.0
# 15                                           \n8/10\n          1.0
# 16                                           \n5/10\n          0.0
# 17                                           \n2/10\n          0.0
# 18                                           \n3/10\n          0.0
# 19                                           \n3/10\n          0.0
# 20                                           \n6/10\n          1.0
# 21                                           \n3/10\n          0.0
# 22                                          \n10/10\n          1.0
# 23                                           \n8/10\n          1.0
# 24                                          \n10/10\n          1.0
# 25                                           \n6/10\n          1.0
# 26                                           \n3/10\n          0.0
# 27                                           \n5/10\n          0.0
# ..                                                ...          ...
# 0                                            \n8/10\n          1.0
# 1                                           \n10/10\n          1.0
# 2                                            \n9/10\n          1.0
# 3                                            \n7/10\n          1.0
# 0                                            \n6/10\n          1.0
# 1                                            \n5/10\n          1.0
# 2                                            \n6/10\n          1.0
# 3                                            \n3/10\n          0.0
# 4                                            \n5/10\n          1.0
# 5                                            \n5/10\n          1.0
# 6                                            \n4/10\n          1.0
# 7                                            \n5/10\n          1.0
# 8                                            \n7/10\n          1.0
# 9                                            \n7/10\n          1.0
# 10                                           \n4/10\n          0.0
# 11                                           \n4/10\n          0.0
# 12                                           \n2/10\n          0.0
# 13                                           \n1/10\n          0.0
# 14                                           \n2/10\n          0.0
# 15  \r\n                        na\r\n            ...          0.0
# 16  \r\n                        na\r\n            ...          0.0
# 17  \r\n                        na\r\n            ...          0.0
# 18  \r\n                        na\r\n            ...          0.0
# 19  \r\n                        na\r\n            ...          0.0
# 20  \r\n                        na\r\n            ...          0.0
# 21  \r\n                        na\r\n            ...          0.0
# 22  \r\n                        na\r\n            ...          0.0
# 23  \r\n                        na\r\n            ...          0.0
# 0                                            \n8/10\n          1.0
# 1                                            \n8/10\n          1.0
#
#     review_count                          route  seat_comfort       seat_type  \
# 0             20              Moroni to Anjouan           2.0   Economy Class
# 1             20            Anjouan to Dzaoudzi           2.0   Economy Class
# 0             32            Ljubljana to Munich           4.0   Economy Class
# 1              0            Zurich to Ljubljana           2.0   Economy Class
# 2              0                Vienna to Sofia           4.0   Economy Class
# 3              0  Paris to Skopje via Ljubljana           3.0   Economy Class
# 4              0            Ljubljana to Munich           1.0   Economy Class
# 5              0            Ljubljana to Prague           3.0   Economy Class
# 6              0         Frankfurt to Ljubljana           5.0   Economy Class
# 7              0         Ljubljana to Frankfurt           2.0   Economy Class
# 8              0            Ljubljana to Vienna           2.0   Economy Class
# 9              0          Ljubljana to Sarajevo           5.0   Economy Class
# 10             0             Zurich to Ljubjana           3.0   Economy Class
# 11             0           Ljubljana to Munich            3.0   Economy Class
# 12             0            Ljubljana to Zurich           5.0   Economy Class
# 13            11                     LJU to VIE           5.0  Business Class
# 14             0                     LJU to VIE           5.0   Economy Class
# 15            44                     LJU to CPH           4.0  Business Class
# 16             0                     CDG to LJU           3.0   Economy Class
# 17             0                     MUC to LJU           1.0   Economy Class
# 18             0                     LJU to AMS           3.0   Economy Class
# 19             0                     LJU to BRU           2.0   Economy Class
# 20             2                     MAN to LJU           2.0   Economy Class
# 21             0                     LGW to LJU           4.0   Economy Class
# 22             0                     TLL to ARN           5.0   Economy Class
# 23             0                     ZRH to LJU           4.0   Economy Class
# 24             0                     LJU to ZRH           5.0   Economy Class
# 25             0                     LCJ to CDG           3.0   Economy Class
# 26             0                     MUC to PRN           2.0   Economy Class
# 27             0                     LJU to AMS           3.0   Economy Class
# ..           ...                            ...           ...             ...
# 0             21                  Bagan to Heho           4.0   Economy Class
# 1              0                            NaN           5.0   Economy Class
# 2              0                            NaN           NaN   Economy Class
# 3              0                            NaN           NaN   Economy Class
# 0              0                            NaN           NaN     First Class
# 1              0                            NaN           NaN   Economy Class
# 2              0                            NaN           NaN   Economy Class
# 3              0                            NaN           NaN   Economy Class
# 4              0                            NaN           NaN   Economy Class
# 5              0                            NaN           NaN   Economy Class
# 6              0                            NaN           NaN   Economy Class
# 7              0                            NaN           NaN   Economy Class
# 8              0                            NaN           NaN   Economy Class
# 9              0                            NaN           NaN   Economy Class
# 10             0                            NaN           NaN             NaN
# 11             0                            NaN           NaN             NaN
# 12             0                            NaN           NaN             NaN
# 13             0                            NaN           NaN             NaN
# 14             0                            NaN           NaN             NaN
# 15             0                            NaN           NaN             NaN
# 16             0                            NaN           NaN             NaN
# 17             0                            NaN           NaN             NaN
# 18             0                            NaN           NaN             NaN
# 19             0                            NaN           NaN             NaN
# 20             0                            NaN           NaN             NaN
# 21             0                            NaN           NaN             NaN
# 22             0                            NaN           NaN             NaN
# 23             0                            NaN           NaN             NaN
# 0              0           Pokhara to Kathmandu           4.0   Economy Class
# 1              3                     BWA to KTM           3.0   Economy Class
#
#                                                  text  \
# 0   ✅ Trip Verified | Moroni to Anjouan. It is a v...
# 1   ✅ Trip Verified |  Anjouan to Dzaoudzi. A very...
# 0   ✅ Trip Verified | Ljubljana to Munich. The hom...
# 1   Not Verified |  Zurich to Ljubljana. Very poor...
# 2   ✅ Trip Verified |  Vienna to Sofia. The flight...
# 3   ✅ Trip Verified |  We were traveling from Pari...
# 4   ✅ Trip Verified |  Ljubljana to Munich. Adria'...
# 5   ✅ Trip Verified |  A very unpleasant experienc...
# 6   ✅ Trip Verified |  Frankfurt to Ljubljana. Fli...
# 7   ✅ Trip Verified |  Ljubljana to Frankfurt. Fli...
# 8   ✅ Trip Verified |  Ljubljana to Vienna. Overal...
# 9   ✅ Trip Verified | Two nice short flights from ...
# 10  ✅ Verified Review | We were 11 people coming i...
# 11  ✅ Verified Review |  Ljubljana to Munich after...
# 12  ✅ Verified Review | Ljubljana to Zurich on Apr...
# 13  ✅ Verified Review |  Ljubljana to Vienna. Afte...
# 14  ✅ Verified Review |  Two very short flights wi...
# 15  ✅ Verified Review |  I boarded the CRJ900 flig...
# 16  ✅ Verified Review |  Fly only if no other conn...
# 17  ✅ Verified Review |  Munich to Ljubljana. Adri...
# 18  ✅ Verified Review |  Ljubljana to Amsterdam. F...
# 19  ✅ Verified Review |  Ljubljana to Brussels. Tw...
# 20  Booked this flight after many years using Easy...
# 21  ✅ Verified Review |  Gatwick to Ljubljana. Do ...
# 22  ✅ Verified Review |  Tallinn to Stockholm with...
# 23  Flew roundtrip on this short route from Zurich...
# 24  ✅ Verified Review |  Two short flights with Ad...
# 25  Lodz to Paris CDG and Munich to Lodz with Adri...
# 26  Adria Airways flight from Pristina to Munich w...
# 27  Ljubljana to Amsterdam in Adria Airways Econom...
# ..                                                ...
# 0   ✅ Verified Review |  Bagan to Heho. Very short...
# 1   Took the 4 tourist flights around Myanmar all ...
# 2   We were booked to take 4 flights on Yangon in ...
# 3   RGN-MDL on ATR . We were a bit sceptical when ...
# 0   Beirut to Sana'a on A330. Yemenia offers a Fir...
# 1   Sanah to Mumbai on A330. A full flight but the...
# 2   Djibouti-Sana'a. There was a small delay leavi...
# 3   Addis Ababa to Sana'a on Yemenia proved a dubi...
# 4   Aden-Dubai on A310. Check-in swift and airside...
# 5   Sana'a-Taiz B737-800 on domestic half-hour fli...
# 6   Addis Ababa to Sanaa. Flight leaves Addis earl...
# 7   Sana'a-Paris on A330. On-time departure in spi...
# 8   RUH-Sana'a return on time on both legs. RUH-SH...
# 9   ADD-AMM via Sanaa. Overnight in Sanaa where Ye...
# 10  Addis Ababa to Cairo via Sana'a. I was pleasan...
# 11  The tickets were the cheapest available. The S...
# 12  The return tickets London to Bangladesh were c...
# 13  I bought the ticket as it was the cheapest ava...
# 14  Jeddah-Sanaa-Paris return. On the way back I h...
# 15  Cairo to Sanaa and back. The service was good....
# 16  London to Aden (direct flight). Everything was...
# 17  I flew 2 international flights London - Sana'a...
# 18  I had a fully reconfirmed ticket from Sana'a t...
# 19  I fly Yemenia every six months on the route Ri...
# 20  London - Sana'a to Jakarta and found the servi...
# 21  I travelled on Yemenia several times. The main...
# 22  Last summer we flew Sana'a - London return. I ...
# 23  My trip was from Paris to Sana'a as a tourist ...
# 0   ✅ Trip Verified |  Pokhara to Kathmandu. I rec...
# 1   ✅ Verified Review |  I flew Yeti Airlines, Jun...
#
#                                           text_header  traveller_type  \
# 0                                "Not a good airline"    Solo Leisure
# 1                      "flight was fortunately short"    Solo Leisure
# 0                                 "the crew was nice"  Family Leisure
# 1                       "Very bad experience overall"        Business
# 2                              "bad customer service"  Family Leisure
# 3                                 "overall very poor"    Solo Leisure
# 4                               "Would not fly again"        Business
# 5                        "very unpleasant experience"  Couple Leisure
# 6                       "Flight was very comfortable"        Business
# 7                     "delayed for more than 2 hours"    Solo Leisure
# 8             "should be ashamed of their operations"    Solo Leisure
# 9                            "Two nice short flights"        Business
# 10                            "extremely bad service"  Couple Leisure
# 11                     "never fly this airline again"  Family Leisure
# 12                    "can't remember a flight delay"        Business
# 13                      "seat was quite comfortable "    Solo Leisure
# 14                     "nice and comfortable flights"        Business
# 15                            "what a great surprise"    Solo Leisure
# 16  "value for money is not there nor the experience"        Business
# 17                      "fleet is tired and outdated"    Solo Leisure
# 18                   "underwhelming and unimpressive"    Solo Leisure
# 19                       "very different experiences"  Couple Leisure
# 20                   "staff were all pleasant enough"  Family Leisure
# 21                 "Adria do not take criticism well"  Couple Leisure
# 22                        "Clean and fresh aircraft "    Solo Leisure
# 23                          "the airline did its job"        Business
# 24                    "nice and professional service"    Solo Leisure
# 25                        "cabin staff rather absent"    Solo Leisure
# 26                          "never flying them again"    Solo Leisure
# 27                      "similar to low cost airline"  Couple Leisure
# ..                                                ...             ...
# 0                          "All in all a good flight"    Solo Leisure
# 1                      Yangon Airways customer review             NaN
# 2                      Yangon Airways customer review             NaN
# 3                      Yangon Airways customer review             NaN
# 0                             Yemenia customer review             NaN
# 1                             Yemenia customer review             NaN
# 2                             Yemenia customer review             NaN
# 3                             Yemenia customer review             NaN
# 4                             Yemenia customer review             NaN
# 5                             Yemenia customer review             NaN
# 6                             Yemenia customer review             NaN
# 7                             Yemenia customer review             NaN
# 8                             Yemenia customer review             NaN
# 9                             Yemenia customer review             NaN
# 10                            Yemenia customer review             NaN
# 11                            Yemenia customer review             NaN
# 12                            Yemenia customer review             NaN
# 13                            Yemenia customer review             NaN
# 14                            Yemenia customer review             NaN
# 15                            Yemenia customer review             NaN
# 16                            Yemenia customer review             NaN
# 17                            Yemenia customer review             NaN
# 18                            Yemenia customer review             NaN
# 19                            Yemenia customer review             NaN
# 20                            Yemenia customer review             NaN
# 21                            Yemenia customer review             NaN
# 22                            Yemenia customer review             NaN
# 23                            Yemenia customer review             NaN
# 0                    "I would fly this airline again"    Solo Leisure
# 1                           "cabin crew was friendly"        Business
#
#     value_for_money    airline_name    airline_code
# 0               2.0     AB Aviation     ab-aviation
# 1               2.0     AB Aviation     ab-aviation
# 0               5.0   Adria Airways   adria-airways
# 1               1.0   Adria Airways   adria-airways
# 2               1.0   Adria Airways   adria-airways
# 3               2.0   Adria Airways   adria-airways
# 4               1.0   Adria Airways   adria-airways
# 5               1.0   Adria Airways   adria-airways
# 6               5.0   Adria Airways   adria-airways
# 7               1.0   Adria Airways   adria-airways
# 8               3.0   Adria Airways   adria-airways
# 9               3.0   Adria Airways   adria-airways
# 10              1.0   Adria Airways   adria-airways
# 11              2.0   Adria Airways   adria-airways
# 12              4.0   Adria Airways   adria-airways
# 13              4.0   Adria Airways   adria-airways
# 14              4.0   Adria Airways   adria-airways
# 15              4.0   Adria Airways   adria-airways
# 16              1.0   Adria Airways   adria-airways
# 17              1.0   Adria Airways   adria-airways
# 18              2.0   Adria Airways   adria-airways
# 19              4.0   Adria Airways   adria-airways
# 20              4.0   Adria Airways   adria-airways
# 21              3.0   Adria Airways   adria-airways
# 22              5.0   Adria Airways   adria-airways
# 23              4.0   Adria Airways   adria-airways
# 24              5.0   Adria Airways   adria-airways
# 25              3.0   Adria Airways   adria-airways
# 26              1.0   Adria Airways   adria-airways
# 27              2.0   Adria Airways   adria-airways
# ..              ...             ...             ...
# 0               4.0  Yangon Airways  yangon-airways
# 1               5.0  Yangon Airways  yangon-airways
# 2               4.0  Yangon Airways  yangon-airways
# 3               4.0  Yangon Airways  yangon-airways
# 0               4.0         Yemenia         yemenia
# 1               4.0         Yemenia         yemenia
# 2               4.0         Yemenia         yemenia
# 3               4.0         Yemenia         yemenia
# 4               4.0         Yemenia         yemenia
# 5               4.0         Yemenia         yemenia
# 6               4.0         Yemenia         yemenia
# 7               4.0         Yemenia         yemenia
# 8               4.0         Yemenia         yemenia
# 9               4.0         Yemenia         yemenia
# 10              NaN         Yemenia         yemenia
# 11              NaN         Yemenia         yemenia
# 12              NaN         Yemenia         yemenia
# 13              NaN         Yemenia         yemenia
# 14              NaN         Yemenia         yemenia
# 15              NaN         Yemenia         yemenia
# 16              NaN         Yemenia         yemenia
# 17              NaN         Yemenia         yemenia
# 18              NaN         Yemenia         yemenia
# 19              NaN         Yemenia         yemenia
# 20              NaN         Yemenia         yemenia
# 21              NaN         Yemenia         yemenia
# 22              NaN         Yemenia         yemenia
# 23              NaN         Yemenia         yemenia
# 0               5.0   Yeti Airlines   yeti-airlines
# 1               5.0   Yeti Airlines   yeti-airlines
#
# [93793 rows x 19 columns]

# %%
airline_raw = pd.DataFrame.from_dict(airline_raw_list)

# %%
#reviews_raw.to_csv("reviews_raw.csv", index=False)

# %%
#airline_raw.to_csv("airline_raw.csv", index=False)
